# %%
# %pwd
# Out:
# '/content'

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Your API Key")
project = rf.workspace("transportation-s05tr").project("helmet-7logd")
dataset = project.version(6).download("yolov8")

# %%
cd helmet-6
# Out:
# /content/helmet-6

# %%
# %pwd
# Out:
# '/content/helmet-6'

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 115MB/s]

# %%
# Train the model
results = model.train(data='data.yaml', epochs=30)
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from PIL import Image
Image.open('/content/helmet-6/runs/detect/train/results.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
Image.open('/content/helmet-6/runs/detect/train/confusion_matrix.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>

# %%
Image.open('/content/helmet-6/runs/detect/train/labels.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1600>

# %%
Image.open('/content/helmet-6/runs/detect/train/F1_curve.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>

# %%
new_model = YOLO('/content/helmet-6/runs/detect/train/weights/best.pt')

# %%
results = new_model('/content/helmet-6/test/images/-239-_jPG.rf.1fc7812a905eadf2c68ea5e76ca75087.jpg')
# Out:
# image 1/1 /content/helmet-6/test/images/-239-_jPG.rf.1fc7812a905eadf2c68ea5e76ca75087.jpg: 640x640 1 nohelmet, 15.9ms
# Speed: 1.9ms preprocess, 15.9ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
